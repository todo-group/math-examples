# %%
# %matplotlib inline
import numpy
from matplotlib import pyplot
from mpl_toolkits.mplot3d import Axes3D
import sympy

# %%
def f(x, y):
    return x**2 + 2 * x * y + y**3;

x, y = numpy.mgrid[-5:5:0.2, -5:5:0.2];

fig = pyplot.figure();
ax = fig.add_subplot(111, projection='3d');
ax.plot_surface(x, y, f(x, y));

# %%
# y = 1 に沿った断面
x = numpy.linspace(-5,5);
z = f(x, 1);
pyplot.plot(x, z);

# %%
# x = 2 に沿った断面
y = numpy.linspace(-5,5);
z = f(2, y);
pyplot.plot(y, z);

# %%
# (x,y) = (2,1) におけるxに関する偏微分係数
x = numpy.linspace(-5,5);
z1 = f(x, 1);
z2 = 6 * (x - 2) + 9;
pyplot.plot(x, z1);
pyplot.plot(x, z2);

# %%
# (x,y) = (2,1) におけるyに関する偏微分係数
y = numpy.linspace(-5,5);
z1 = f(2, y);
z2 = 7 * (y - 1) + 9;
pyplot.plot(y, z1);
pyplot.plot(y, z2);

# %%
x = sympy.Symbol('x');
y = sympy.Symbol('y');
f(x, y)
# Out:
# x**2 + 2*x*y + y**3

# %%
f(x, 1)
# Out:
# x**2 + 2*x + 1

# %%
sympy.diff(f(x, y), x)
# Out:
# 2*x + 2*y

# %%
a = sympy.diff(f(x, y), x).subs([(x, 2), (y, 1)]);
b = f(2, 1);
print(a, b);
sympy.plot(f(x, 1), a*(x-2)+b, (x, -5, 5));
# Out:
# 6 9

# %%
a = sympy.diff(f(x, y), y).subs([(x, 2), (y, 1)]);
b = f(2, 1);
print(a, b);
sympy.plot(f(2, y), a*(y-1)+b, (y, -5, 5));
# Out:
# 7 9
